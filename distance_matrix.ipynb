# %%
import pandas as pd
from scipy.spatial import distance_matrix
data = [[1, 1], [2, 3], [3, 4], [4, 2], [8, 2], [8, 4], [9, 5]]
ctys = ['a', 'b', 'c', 'd', 'e', 'f', 'g']
df = pd.DataFrame(data, columns=['xcord', 'ycord'], index=ctys)

# %%
pd.DataFrame(distance_matrix(df.values, df.values), index=df.index, columns=df.index)
# Out:
#           a         b         c         d         e         f         g
# a  0.000000  2.236068  3.605551  3.162278  7.071068  7.615773  8.944272
# b  2.236068  0.000000  1.414214  2.236068  6.082763  6.082763  7.280110
# c  3.605551  1.414214  0.000000  2.236068  5.385165  5.000000  6.082763
# d  3.162278  2.236068  2.236068  0.000000  4.000000  4.472136  5.830952
# e  7.071068  6.082763  5.385165  4.000000  0.000000  2.000000  3.162278
# f  7.615773  6.082763  5.000000  4.472136  2.000000  0.000000  1.414214
# g  8.944272  7.280110  6.082763  5.830952  3.162278  1.414214  0.000000
